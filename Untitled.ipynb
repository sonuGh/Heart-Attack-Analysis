# %%
import numpy as np 
import pandas as pd  
import seaborn as sns 
import matplotlib.pyplot as plt 
import plotly.express as px 
df= pd.read_csv('hearts.csv') 
print(df.head())
df.shape
# Out:
#    age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 0   63    1   3     145   233    1        0       150     0      2.3    0
# 1   37    1   2     130   250    0        1       187     0      3.5    0
# 2   41    0   1     130   204    0        0       172     0      1.4    2
# 3   56    1   1     120   236    0        1       178     0      0.8    2
# 4   57    0   0     120   354    0        1       163     1      0.6    2
#
#    caa  thall  output
# 0    0      1       1
# 1    0      2       1
# 2    0      2       1
# 3    0      2       1
# 4    0      2       1
# (303, 14)

# %%
df.head()
# Out:
#    age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 0   63    1   3     145   233    1        0       150     0      2.3    0
# 1   37    1   2     130   250    0        1       187     0      3.5    0
# 2   41    0   1     130   204    0        0       172     0      1.4    2
# 3   56    1   1     120   236    0        1       178     0      0.8    2
# 4   57    0   0     120   354    0        1       163     1      0.6    2
#
#    caa  thall  output
# 0    0      1       1
# 1    0      2       1
# 2    0      2       1
# 3    0      2       1
# 4    0      2       1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       303 non-null    int64
#  1   sex       303 non-null    int64
#  2   cp        303 non-null    int64
#  3   trtbps    303 non-null    int64
#  4   chol      303 non-null    int64
#  5   fbs       303 non-null    int64
#  6   restecg   303 non-null    int64
#  7   thalachh  303 non-null    int64
#  8   exng      303 non-null    int64
#  9   oldpeak   303 non-null    float64
#  10  slp       303 non-null    int64
#  11  caa       303 non-null    int64
#  12  thall     303 non-null    int64
#  13  output    303 non-null    int64
# dtypes: float64(1), int64(13)
# memory usage: 33.3 KB

# %%
df.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trtbps      0
# chol        0
# fbs         0
# restecg     0
# thalachh    0
# exng        0
# oldpeak     0
# slp         0
# caa         0
# thall       0
# output      0
# dtype: int64

# %%
train_df=df['sex'].replace([0,1],['Female','Male'], inplace=False) 
train_df
# Out:
# 0        Male
# 1        Male
# 2      Female
# 3        Male
# 4      Female
#         ...
# 298    Female
# 299      Male
# 300      Male
# 301      Male
# 302    Female
# Name: sex, Length: 303, dtype: object

# %%
df.duplicated().sum()
# Out:
# 1

# %%
df.drop_duplicates(keep='first') 
df.shape
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       303 non-null    int64
#  1   sex       303 non-null    int64
#  2   cp        303 non-null    int64
#  3   trtbps    303 non-null    int64
#  4   chol      303 non-null    int64
#  5   fbs       303 non-null    int64
#  6   restecg   303 non-null    int64
#  7   thalachh  303 non-null    int64
#  8   exng      303 non-null    int64
#  9   oldpeak   303 non-null    float64
#  10  slp       303 non-null    int64
#  11  caa       303 non-null    int64
#  12  thall     303 non-null    int64
#  13  output    303 non-null    int64
# dtypes: float64(1), int64(13)
# memory usage: 33.3 KB

# %%
dict = {}
for i in list(df.columns):
    dict[i] = df[i].value_counts().shape[0]

pd.DataFrame(dict,index=["unique count"]).transpose()
# Out:
#           unique count
# sex                  2
# cp                   4
# trtbps              49
# chol               152
# fbs                 41
# restecg              3
# thalachh            91
# exng                 2
# oldpeak             40
# slp                  3
# caa                  5
# thall                4
# output               2

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       303 non-null    int64
#  1   sex       303 non-null    int64
#  2   cp        303 non-null    int64
#  3   trtbps    303 non-null    int64
#  4   chol      303 non-null    int64
#  5   fbs       303 non-null    int64
#  6   restecg   303 non-null    int64
#  7   thalachh  303 non-null    int64
#  8   exng      303 non-null    int64
#  9   oldpeak   303 non-null    float64
#  10  slp       303 non-null    int64
#  11  caa       303 non-null    int64
#  12  thall     303 non-null    int64
#  13  output    303 non-null    int64
# dtypes: float64(1), int64(13)
# memory usage: 33.3 KB

# %%
#IQR

q1= df.quantile(0.25) 
q3= df.quantile(0.75) 
IQR= q3-q1 
upper_outlier= q3+IQR*1.5 
lower_outlier= q1-IQR*1.5 

upper_dict=dict(upper_outlier) 
lower_dict= dict(lower_outlier) 

for a,b in df.items(): 
    b_col = b[( b<= lower_dict[a]) | (b >= upper_dict[a])] 
    perc = np.shape(b_col)[0] * 100.0 / np.shape(df)[0] 
    print("Column {} outliers = {} => {}%".format(a,len(b_col),round((perc),2)))
# Out:
# Column age outliers = 0 => 0.0%
# Column sex outliers = 0 => 0.0%
# Column cp outliers = 0 => 0.0%
# Column trtbps outliers = 13 => 4.29%
# Column chol outliers = 5 => 1.65%
# Column fbs outliers = 303 => 100.0%
# Column restecg outliers = 0 => 0.0%
# Column thalachh outliers = 1 => 0.33%
# Column exng outliers = 0 => 0.0%
# Column oldpeak outliers = 8 => 2.64%
# Column slp outliers = 0 => 0.0%
# Column caa outliers = 25 => 8.25%
# Column thall outliers = 2 => 0.66%
# Column output outliers = 0 => 0.0%

# %%
#transformation of outliers 
df["fbs"]= np.log(df.age) 
df["trtbps"]= np.log(df.trtbps) 
df["chol"]= np.log(df.chol) 
df["thalachh"]= np.log(df.thalachh)

print("---Log Transform of outliers performed---")
# Out:
# ---Log Transform of outliers performed---

# %%
#Exploratory Data Analysis 
#Analysis-1 
plt.figure(figsize=(20,10)) 
sns.countplot(x=df["age"]) 
plt.title('Patients age count',fontsize=20) 
plt.xlabel('Age',fontsize=20)
plt.ylabel('Count',fontsize=20) 
plt.show()

# %%
s=df["sex"].value_counts().reset_index() 
px.pie(s,names="sex",values="count",title='percentage of male & female patients')
# Out:
# <div>                            <div id="a5aa7e6b-e247-4836-88d4-568b5d890757" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a5aa7e6b-e247-4836-88d4-568b5d890757")) {                    Plotly.newPlot(                        "a5aa7e6b-e247-4836-88d4-568b5d890757",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"sex=%{label}<br>count=%{value}<extra></extra>","labels":[1,0],"legendgroup":"","name":"","showlegend":true,"values":[207,96],"type":"pie"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444
# ...

# %%
#Analysis-2

plt.figure(figsize=(20,10)) 
sns.countplot(x=df["trtbps"]) 
plt.title('Maximum Blood Pressure',fontsize=20) 
plt.xlabel('BP',fontsize=20)
plt.ylabel('Count',fontsize=20) 
plt.show()

# %%
plt.figure(figsize=(20,10)) 
sns.countplot(x=df["chol"]) 
plt.title('Maximum cholesterol',fontsize=20) 
plt.xlabel('Cholestrol',fontsize=20)
plt.ylabel('Count',fontsize=20) 
plt.show()

# %%
plt.figure(figsize=(20,10)) 
sns.countplot(x=df["thalachh"]) 
plt.title('Maximum Heart Rate',fontsize=20) 
plt.xlabel('Heart Rate',fontsize=20)
plt.ylabel('Count',fontsize=20) 
plt.show()

# %%
sns.lineplot(x='age', y='trtbps', data=df)
plt.show()

# %%
#Basics of Machine learning 
# droping the column 'drop' as it's unecessary for the predictions 
X= df.drop('output', axis=1) 
y= df['output'] 
#importing sklearn libraries 
from sklearn.preprocessing import StandardScaler 
from sklearn.model_selection import train_test_split 
from sklearn.neighbors import KNeighborsClassifier 
from sklearn.linear_model import LogisticRegression 
from sklearn.ensemble import RandomForestClassifier 
from sklearn.model_selection import cross_val_score 
from sklearn import metrics

#Fitting & transforming the data 
scaler=StandardScaler()

X= pd.DataFrame(scaler.fit_transform(X)) 
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=0) 
knn=KNeighborsClassifier(n_neighbors=5) 
knn.fit(X_train,y_train) 
y_pred=knn.predict(X_test) 
print(metrics.classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.83      0.70      0.76        27
#            1       0.79      0.88      0.83        34
#
#     accuracy                           0.80        61
#    macro avg       0.81      0.79      0.80        61
# weighted avg       0.81      0.80      0.80        61

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.1, random_state = 3)
print("X_train: {}".format(X_train.shape))
print("X_test: {}".format(X_test.shape))
print("y_train: {}".format(y_train.shape))
print("y_test: {}".format(y_test.shape))
# Out:
# X_train: (272, 13)
# X_test: (31, 13)
# y_train: (272,)
# y_test: (31,)

# %%
df.head()
# Out:
#    age  sex  cp    trtbps      chol       fbs  restecg  thalachh  exng  \
# 0   63    1   3  4.976734  5.451038  4.143135        0  5.010635     0
# 1   37    1   2  4.867534  5.521461  3.610918        1  5.231109     0
# 2   41    0   1  4.867534  5.318120  3.713572        0  5.147494     0
# 3   56    1   1  4.787492  5.463832  4.025352        1  5.181784     0
# 4   57    0   0  4.787492  5.869297  4.043051        1  5.093750     1
#
#    oldpeak  slp  caa  thall  output
# 0      2.3    0    0      1       1
# 1      3.5    0    0      2       1
# 2      1.4    2    0      2       1
# 3      0.8    2    0      2       1
# 4      0.6    2    0      2       1

# %%
#checking the accuracy of the model 
model= RandomForestClassifier()

model.fit(X_train,y_train) 
predict_df=model.predict(X_test) 
metrics.accuracy_score(y_test,predict_df)
# Out:
# 0.819672131147541

# %%
print(df.trtbps.unique())
print(df['trtbps'].value_counts())
print(df.trtbps.nunique())
# Out:
# [4.97673374 4.86753445 4.78749174 4.94164242 5.14749448 5.01063529
#  4.70048037 4.90527478 5.07517382 4.65396035 4.82831374 4.95582706
#  5.04342512 4.6443909  4.92725369 4.85203026 4.68213123 4.8978398
#  5.25749537 4.79579055 4.56434819 4.83628191 4.65396035 5.19849703
#  4.75359019 4.68213123 4.8598124  4.78749174 4.71849887 4.85203026
#  4.69134788 4.72738782 4.59511985 5.17614973 4.94875989 4.91265489
#  4.57471098 4.84418709 4.63472899 4.82028157 4.47733681 5.27299956
# ...

# %%
fig, axarr = plt.subplots(4, 2, figsize=(12, 18))
df.groupby('age')['trtbps'].mean().sort_values(ascending=False).plot.bar(ax=axarr[0][0], fontsize=12)
axarr[0][0].set_title("Age Vs BP", fontsize=18)
plt.subplots_adjust(hspace=1.0)
plt.subplots_adjust(wspace=.5)
sns.despine()

# %%
plt.scatter(df.age, df.trtbps)
plt.title('Hours Studied vs. Exam Score')
plt.xlabel('Hours Studied')
plt.ylabel('Exam Score')
# Out:
# Text(0, 0.5, 'Exam Score')

# %%
import matplotlib.pyplot as plt

# Assuming your DataFrame is named 'df'
plt.scatter(df['age'], df['trtbps'])
plt.xlabel('Age')
plt.ylabel('BP')
plt.title('Age vs. BP')
plt.xticks(rotation='vertical')
plt.show()

# %%
#df = df.set_index('age')
#df=df.reset_index('age')
num_cols = ['trtbps', 'chol', 'thalachh']
df[num_cols] = df[num_cols].astype(float)

df[num_cols].plot()
plt.xlabel('Age')
plt.ylabel('Values')
plt.title('Variation of Columns over Time')
plt.xticks(range(len(df.index)), df.index)
plt.show()

# %%
plt.figure(figsize=(20,12))
sns.set_context('notebook',font_scale = 1.3)
sns.heatmap(df.corr(),annot=True,linewidth =2)
plt.tight_layout()

# %%
#Let’s check the range of age in the dataset.

minAge=min(df.age)
maxAge=max(df.age)
meanAge=df.age.mean()
print('Min Age :',minAge)
print('Max Age :',maxAge)
print('Mean Age :',meanAge)
# Out:
# Min Age : 29
# Max Age : 77
# Mean Age : 54.366336633663366

# %%
Young = df[(df.age>=29)&(df.age<40)]
Middle = df[(df.age>=40)&(df.age<55)]
Elder = df[(df.age>55)]

plt.figure(figsize=(23,10))
sns.set_context('notebook',font_scale = 1.5)
sns.barplot(x=['young ages','middle ages','elderly ages'],y=[len(Young),len(Middle),len(Elder)])
plt.tight_layout()

# %%
#To prove the above inference we will plot the pie chart.

colors = ['blue','green','yellow']
explode = [0,0,0.1]
plt.figure(figsize=(10,10))
sns.set_context('notebook',font_scale = 1.2)
plt.pie([len(Young),len(Middle),len(Elder)],labels=['young ages','middle ages','elderly ages'],explode=explode,colors=colors, autopct='%1.1f%%')
plt.tight_layout()

# %%
#Sex(“sex”) Feature Analysis
plt.figure(figsize=(18,9))
sns.set_context('notebook',font_scale = 1.5)
sns.countplot(df['sex'])
plt.tight_layout()

# %%
plt.figure(figsize=(18,9))
sns.set_context('notebook',font_scale = 1.5)
sns.countplot(df['sex'],hue=df["slp"])
plt.tight_layout()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[176], line 3
#       1 plt.figure(figsize=(18,9))
#       2 sns.set_context('notebook',font_scale = 1.5)
# ----> 3 sns.countplot(df['sex'],hue=df["slp"])
#       4 plt.tight_layout()
#
# File ~\anaconda3\Lib\site-packages\seaborn\categorical.py:2943, in countplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, width, dodge, ax, **kwargs)
#    2940 elif x is not None and y is not None:
#    2941     raise ValueError("Cannot pass values for both `x` and `y`")
# -> 2943 plotter = _CountPlotter(
#    2944     x, y, hue, data, order, hue_order,
#    2945     estimator, errorbar, n_boot, units, seed,
#    2946     orient, color, palette, saturation,
#    2947     width, errcolor, errwidth, capsize, dodge
#    2948 )
#    2950 plotter.value_label = "count"
#    2952 if ax is None:
#
# ...
